# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika2713/skill-wallet/blob/main/entity%20relation%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📊 Project Documentation: Entity Relationship Diagram (ERD)

> Note: If you are viewing this notebook inside Google Colab, the diagram below will render as text/code. Once pushed to GitHub, it will automatically generate as a visual database schema graph.

```mermaid
erDiagram
    USERS ||--o{ APPLICANT_DETAILS : "manages/submits"
    APPLICANT_DETAILS ||--o{ CREDIT_HISTORY : "has"
    APPLICANT_DETAILS ||--|| APPROVAL_PREDICTION : "receives"
    ML_MODEL ||--o{ APPROVAL_PREDICTION : "generates"
    CREDIT_HISTORY ||--|| APPROVAL_PREDICTION : "informs"

    USERS {
        int UserID PK
        string Name
        string Email
        string Password
        string Role
    }

    APPLICANT_DETAILS {
        int ApplicantID PK
        int UserID FK
        string IncomeType
        string EducationType
        string FamilyStatus
        string HousingType
        int EmploymentDays
    }

    CREDIT_HISTORY {
        int HistoryID PK
        int ApplicantID FK
        int Credit_Score
        string Prior_Default
    }

    ML_MODEL {
        int ModelID PK
        string Model_Name
        string Version
    }

    APPROVAL_PREDICTION {
        int PredictionID PK
        int ApplicantID FK
        int ModelID FK
        int Approval_Status
    }
```
